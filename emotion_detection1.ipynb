# %% [markdown]
# <a href="https://colab.research.google.com/github/pav-i/emotion-detection/blob/main/emotion_detection1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install deepface

# %%
import cv2
import matplotlib.pyplot as plt
from deepface import DeepFace

# read image
img = cv2.imread('/content/happy.jpg')

# call imshow() using plt object
plt.imshow(img[:,:,::-1])

# display that image
plt.show()

# storing the result
result = DeepFace.analyze(img,actions=['emotion'])

# print result
print(result)
# Out:
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00,  9.33it/s]
# [{'emotion': {'angry': 6.931102524281469e-15, 'disgust': 7.448939004406998e-21, 'fear': 8.256508971064757e-17, 'happy': 100.0, 'sad': 1.4933863192495198e-14, 'surprise': 8.463781569047549e-12, 'neutral': 6.504405014595704e-07}, 'dominant_emotion': 'happy', 'region': {'x': 70, 'y': 34, 'w': 119, 'h': 119}}]
